# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import numpy as np


import matplotlib.pyplot as plt
from matplotlib import pyplot
import matplotlib 
import matplotlib.cm as cm
import matplotlib.animation as animation
import matplotlib.gridspec as gridspec
from matplotlib.legend_handler import HandlerPatch
import matplotlib.patches as mpatches
import seaborn as sns
import matplotlib as mpl
import pickle as pkl
import os
#from kcrf.estimator import simple_estimator as np_simple_est
import time 
import csv
import torch
from torch.autograd import Variable
import torch.optim as optim
from copy import deepcopy
import pandas as pd
import hydra
from helpers import *
from matplotlib.colors import hsv_to_rgb
import matplotlib.colors as mpl_colors
from math import log10

from hydra.core.hydra_config import HydraConfig
from omegaconf import DictConfig, ListConfig, OmegaConf
from experimentalist.reader import Reader
import json
#from Experimentalist.utils import load_dict_from_json
from sympy import latex, sympify, Symbol
import experimentalist as expy

#from Experimentalist.utils import group_by, aggregate, Map, extract_data_from_config
#from Experimentalist.helper import safe_argmin, safe_argmax, get_scalar_data

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
def save(n, ext='.pdf', save_figs=True,dirname = '../data/figures', **kwargs):
    if save_figs==True:
        kwargs.setdefault('bbox_inches', 'tight')
        kwargs.setdefault('pad_inches', 0.1)
        kwargs.setdefault('transparent', True)
        plt.savefig(os.path.join(dirname, n + ext), **kwargs)

# %% [markdown]
# # Querying a database

# %%
log_name = 'multitask_cifar100'
out_dir = '../data/outputs'
reader = expy.Reader(os.path.join(out_dir,log_name), reload=True)

query_1 = ["metadata.selection.name == BGS",
        "metadata.selection.linear_solver.lr == 0.001",
        "metadata.selection.optimizer.lr == 0.1",
        "metadata.selection.linear_op.stochastic == True",
        "metadata.selection.linear_op.compute_new_grad == True"]
query_1  = "&".join(query_1)


query_2 = ["metadata.selection.name == BGS",
        "metadata.selection.linear_solver.lr == 0.001",
        "metadata.selection.optimizer.lr == 0.1",
        "metadata.selection.linear_op.stochastic == False"]
query_2  = "&".join(query_2)

query = query_1 + "|" + query_2
query = ""
out = reader.search(query)

#query = {'metadata.selection.name' : ["BGS"],
#        'metadata.selection.linear_solver.lr': [0.001],
#        'metadata.selection.optimizer.lr': [0.1],
#        'metadata.selection.linear_op.stochastic':[False],
#        }




#out += reader.search(query)

# %%
len(out.collection_list[0].config)
# Out:
# 12

# %% [markdown]
# # Adding data to the query output

# %%
#from experimentalist.maps import Path, Last, AggMin, AggMax, AggAvgStd

out.add([expy.maps.Path(reader.root_dir)
          ])

out.add([expy.maps.Last("metrics.train_upper_loss"),
          expy.maps.Last("metrics.train_upper_acc"),
          "metrics.train_upper_loss",
          "metrics.train_upper_acc"
          ])

# %% [markdown]
# # Grouping and aggregation

# %%
group_keys = [['metadata.selection.linear_op.compute_new_grad',
              'metadata.selection.compute_latest_correction',
             'metadata.selection.linear_op.stochastic'],
             ['metadata.training.total_epoch']]


aggmaps = [expy.maps.AggMin("metadata.metrics.train_upper_loss_last"),
        expy.maps.AggMax("metadata.metrics.train_upper_acc_last")]

list_config_dicts = out.groupBy(group_keys).agg(aggmaps).toConfigCollection()
list_conf = list_config_dicts['metadata.metrics.train_upper_loss_last_aggmin']


aggmaps = [expy.maps.AggAvgStd("metrics.train_upper_acc"),
        expy.maps.AggAvgStd("metrics.test_upper_acc_all")
        ,"metrics.epoch"]

list_conf.add(aggmaps)

# %% [markdown]
# # Extracting results from list of (aggregated) experiments

# %%
values_list = ["metrics.train_upper_acc_avg",
            "metrics.test_upper_acc_all_avg",
            "metrics.epoch",
            "group_keys_val",
            "group_keys"]
gen_list = list_conf.get(values_list)

# %%
gen_list[0]['group_keys_val']
# Out:
# 'True_True_True-200'

# %%
methods = [data['group_keys_val'] for data in gen_list]
key_name = gen_list[0]['group_keys']+':'
color_dict, labels_dict, linestyles_dict,colors = make_plot_dicts(methods,key_name)
methods, key_name
# Out:
# (['True_True_True-200',
#   'True_False_True-200',
#   'True_True_False-200',
#   'True_False_False-200',
#   'False_True_False-200',
#   'False_False_False-200'],
#  'compute_new_grad-compute_latest_correction-stochastic-total_epoch:')

# %% [markdown]
# # Plotting results

# %%
num_x =2
num_y = 1
avg_time_dict = None
xlabel = ''
ylabel = ''
title  = ''
xlim= [0,200]
ylim = [0,110.]
xlabel = 'Epochs'

methods = [data['group_keys_val'] for data in gen_list]
key_name = gen_list[0]['group_keys']+':'
color_dict, labels_dict, linestyles_dict,colors = make_plot_dicts(methods,key_name)

ynames = ["metrics.train_upper_acc_avg",
            "metrics.test_upper_acc_all_avg"]
fig, ax = plt.subplots(num_y,num_x, figsize=(6*num_x,4*num_y))
for i,yname in enumerate(ynames):
    plot_from_config(ax[i],
                 gen_list,
                 "metrics.epoch",
                 yname,
                 color_dict,
                 labels_dict,
                 linestyles_dict,
                 xscale='linear',
                 yscale = 'linear',
                 ylabel=yname,
                 xlabel= 'Epochs',
                 title= yname ,
                 fontsize=30,
                 xlim=xlim,
                 ylim= ylim,
                 ticks_fontsize=20,
                 with_legend=False)



vals = ax[1].get_yticks()
ax[1].set_yticklabels(['{:,.0%}'.format(x/100.) for x in vals])
vals = ax[0].get_yticks()
ax[0].set_yticklabels(['{:,.0%}'.format(x/100.) for x in vals])

handles, labels = ax[0].get_legend_handles_labels()
ax[1].legend(loc='center left', bbox_to_anchor=(1, 0.5),prop={"size":25})





#fig_name = 'multitask_cifar100_lr_0.001'
#save(fig_name)
# Out:
# /tmp/ipykernel_29363/650994380.py:40: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[1].set_yticklabels(['{:,.0%}'.format(x/100.) for x in vals])
# /tmp/ipykernel_29363/650994380.py:42: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_yticklabels(['{:,.0%}'.format(x/100.) for x in vals])

# %%
query = {'training.trainer_name' : ["examples.multitask.trainer.Trainer"],
        'selection.optimizer.lr': [0.1],}

out = reader.search(query)
#color_dict, labels_dict, linestyles_dict,colors = make_plot_dicts(out)
len(out)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_14088/428181492.py in <module>
#       2         'selection.optimizer.lr': [0.1],}
#       3
# ----> 4 out = reader.search(query)
#       5 #color_dict, labels_dict, linestyles_dict,colors = make_plot_dicts(out)
#       6 len(out)
#
# ~/Documents/projects/Experimentalist/experimentalist/reader.py in search(self, queries_dict)
#      65             Q = make_query(query_dict)
#      66             res += self.runs.search(Q)
# ---> 67         res = ConfigList(res,root_name=self.file_name)
#      68         return ConfigCollection([res])
#      69
#
# ~/Documents/projects/Experimentalist/experimentalist/collections.py in __init__(self, config, root_name, group_keys_val, group_keys)
#      15
#      16     def __init__(self,config, root_name='', group_keys_val='',group_keys=[]):
# ---> 17         if 'hierarchical' in config[0]:
#      18             self.config=config
#      19         else:
#
# IndexError: list index out of range

# %%
val_keys = ['train_upper_loss','train_upper_acc','test_upper_loss_all','test_upper_acc_all']
failed_exps = []
for i,p in enumerate(out):
    try:
        add_res_to_data(p, val_keys, mode='last')
    except:
        failed_exps.append(i)

out = [p  for i,p in enumerate(out) if i not in  failed_exps]
group_keys = [('selection','linear_op','stochastic'),('selection','linear_op','compute_new_grad'),
              ('selection','linear_op','use_new_input')]

group_keys = [('selection','name')]

#group_keys = [('selection','optimizer','lr')]
#variable_keys = [('data','b_size')]
variable_keys = [('training','total_epoch')]
#variable_keys = [('solver','inner_forward','n_iter')]

value_keys = [('results','train_upper_loss'), ('results','test_upper_loss_all'),('results','train_upper_acc'),('results','test_upper_acc_all')]
apply_func = [safeargmin,safeargmin, safeargmax,safeargmax]
aggregate_dict = aggregate_res_dict(out,group_keys, variable_keys, value_keys)
reduced_dict = reduce_res_dict(aggregate_dict, apply_func,variable_keys,sort=True, is_index=True)
list_config_dicts = reduce_collectionDict_to_list(reduced_dict, 0, 'index_results_'+value_keys[0][1])
methods = reduced_dict.keys()
key_name = '-'.join([el[-1] for el in group_keys])+':'

color_dict, labels_dict, linestyles_dict,colors = make_plot_dicts(methods,key_name)

# %%
val_keys = ['train_upper_loss','train_upper_acc','test_upper_loss_all','test_upper_acc_all']
failed_exps = []
for i,p in enumerate(out):
    try:
        add_res_to_data(p, val_keys, mode='last')
    except:
        failed_exps.append(i)

out = [p  for i,p in enumerate(out) if i not in  failed_exps]
group_keys = [('selection','linear_op','stochastic'),('selection','linear_op','compute_new_grad'),
              ('selection','linear_op','use_new_input')]

group_keys = [('selection','name')]

#group_keys = [('selection','optimizer','lr')]
#variable_keys = [('data','b_size')]
variable_keys = [('training','total_epoch')]
#variable_keys = [('solver','inner_forward','n_iter')]

value_keys = [('results','train_upper_loss'), ('results','test_upper_loss_all'),('results','train_upper_acc'),('results','test_upper_acc_all')]
apply_func = [safeargmin,safeargmin, safeargmax,safeargmax]
aggregate_dict = aggregate_res_dict(out,group_keys, variable_keys, value_keys)
reduced_dict = reduce_res_dict(aggregate_dict, apply_func,variable_keys,sort=True, is_index=True)
list_config_dicts = reduce_collectionDict_to_list(reduced_dict, 0, 'index_results_'+value_keys[0][1])
methods = reduced_dict.keys()
key_name = '-'.join([el[-1] for el in group_keys])+':'

color_dict, labels_dict, linestyles_dict,colors = make_plot_dicts(methods,key_name)

# %%
num_x =2
num_y = 1
avg_time_dict = None
xlabel = ''
ylabel = ''
title  = ''
xlim= [0,200]
ylim = [20,80.]
xlabel = 'Epochs'
lw = 3.
ynames = ['train_upper_acc','test_upper_acc_all']
gen_list = make_gens(list_config_dicts,ynames,group_keys)
fig, ax = plt.subplots(num_y,num_x, figsize=(6*num_x,4*num_y))
for i,(gen,yname) in enumerate(zip(gen_list,ynames)):
    plot_from_config(ax[i],
                 gen,
                 color_dict,
                 labels_dict,
                 linestyles_dict,
                 xscale='linear',
                 yscale = 'linear',
                 ylabel=yname,
                 xlabel= 'Epochs',
                 title= yname ,
                 fontsize=30,
                 xlim=xlim,
                 ylim= None,
                 ticks_fontsize=20,
                 lw=lw,
                 with_legend=False)



vals = ax[1].get_yticks()
ax[1].set_yticklabels(['{:,.0%}'.format(x/100.) for x in vals])
vals = ax[0].get_yticks()
ax[0].set_yticklabels(['{:,.0%}'.format(x/100.) for x in vals])

#handles, labels = ax[0].get_legend_handles_labels()
#ax[1].legend(loc='center left', bbox_to_anchor=(1, 0.5),prop={"size":25})

ynames = ['train_upper_loss','test_upper_loss_all']
ylim = [0,2.]
gen_list = make_gens(list_config_dicts,ynames,group_keys)
fig, ax = plt.subplots(num_y,num_x, figsize=(6*num_x,4*num_y))
for i,(gen,yname) in enumerate(zip(gen_list,ynames)):
    plot_from_config(ax[i],
                 gen,
                 color_dict,
                 labels_dict,
                 linestyles_dict,
                 xscale='linear',
                 yscale = 'linear',
                 ylabel=yname,
                 xlabel= 'Epochs',
                 title= yname ,
                 fontsize=30,
                 xlim=xlim,
                 ylim= None,
                 ticks_fontsize=20,
                 lw=lw,
                 with_legend=False)



handles, labels = ax[0].get_legend_handles_labels()
ax[1].legend(loc='center left', bbox_to_anchor=(1, 0.5),prop={"size":25})

ynames = ['upper_grad_norm','dual_var_norm']
ylim = [0,1.]
gen_list = make_gens(list_config_dicts,ynames,group_keys)
fig, ax = plt.subplots(num_y,num_x, figsize=(6*num_x,4*num_y))
for i,(gen,yname) in enumerate(zip(gen_list,ynames)):
    plot_from_config(ax[i],
                 gen,
                 color_dict,
                 labels_dict,
                 linestyles_dict,
                 xscale='linear',
                 yscale = 'linear',
                 ylabel=yname,
                 xlabel= 'Epochs',
                 title= yname ,
                 fontsize=30,
                 xlim=xlim,
                 ylim= None,
                 ticks_fontsize=20,
                 lw=lw,
                 with_legend=False)



handles, labels = ax[0].get_legend_handles_labels()
ax[1].legend(loc='center left', bbox_to_anchor=(1, 0.5),prop={"size":25})



plt.tight_layout()





fig_name = 'multitask_cifar100_total'
save(fig_name)
# Out:
# /tmp/ipykernel_11510/2217834120.py:35: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[1].set_yticklabels(['{:,.0%}'.format(x/100.) for x in vals])
# /tmp/ipykernel_11510/2217834120.py:37: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_yticklabels(['{:,.0%}'.format(x/100.) for x in vals])

# %%
ynames = ['train_upper_acc','test_upper_acc_all']
#ynames = ['train_upper_loss','test_upper_loss_all']
gen_list = make_gens(list_config_dicts,ynames,group_keys)
gen_list[1][0]['y'][-1]
# Out:
# 73.1249988079071

# %%
log_name = 'multitask_cifar100_scheduling_weight_decay'
out_dir = '../data/outputs'
reader = load_method(log_name,out_dir)

query = {'training.trainer_name' : ["examples.multitask.trainer.Trainer"],
        'training.upper.scheduler.use_scheduler': [True],
        }

out = reader.search(query)
#color_dict, labels_dict, linestyles_dict,colors = make_plot_dicts(out)
len(out)
# Out:
# 11

# %%
val_keys = ['train_upper_loss','train_upper_acc','test_upper_loss_all','test_upper_acc_all']
failed_exps = []
for i,p in enumerate(out):
    try:
        add_res_to_data(p, val_keys, mode='last')
    except:
        failed_exps.append(i)

out = [p  for i,p in enumerate(out) if i not in  failed_exps]
group_keys = [('selection','linear_op','stochastic'),('selection','linear_op','compute_new_grad'),
              ('selection','linear_op','use_new_input')]

group_keys = [('selection','name')]

#group_keys = [('selection','optimizer','lr')]
#variable_keys = [('data','b_size')]
variable_keys = [('training','total_epoch')]
#variable_keys = [('solver','inner_forward','n_iter')]

value_keys = [('results','train_upper_loss'), ('results','test_upper_loss_all'),('results','train_upper_acc'),('results','test_upper_acc_all')]
apply_func = [safeargmin,safeargmin, safeargmax,safeargmax]
aggregate_dict = aggregate_res_dict(out,group_keys, variable_keys, value_keys)
reduced_dict = reduce_res_dict(aggregate_dict, apply_func,variable_keys,sort=True, is_index=True)
list_config_dicts = reduce_collectionDict_to_list(reduced_dict, 0, 'index_results_'+value_keys[3][1])
methods = reduced_dict.keys()
key_name = '-'.join([el[-1] for el in group_keys])+':'

color_dict, labels_dict, linestyles_dict,colors = make_plot_dicts(methods,key_name)

# %%
num_x =2
num_y = 1
avg_time_dict = None
xlabel = ''
ylabel = ''
title  = ''
xlim= [0,200]
ylim = [20,80.]
xlabel = 'Epochs'
lw = 3.
ynames = ['train_upper_acc','test_upper_acc_all']
gen_list = make_gens(list_config_dicts,ynames,group_keys)
fig, ax = plt.subplots(num_y,num_x, figsize=(6*num_x,4*num_y))
for i,(gen,yname) in enumerate(zip(gen_list,ynames)):
    plot_from_config(ax[i],
                 gen,
                 color_dict,
                 labels_dict,
                 linestyles_dict,
                 xscale='linear',
                 yscale = 'linear',
                 ylabel=yname,
                 xlabel= 'Epochs',
                 title= yname ,
                 fontsize=30,
                 xlim=xlim,
                 ylim= None,
                 ticks_fontsize=20,
                 lw=lw,
                 with_legend=False)



vals = ax[1].get_yticks()
ax[1].set_yticklabels(['{:,.0%}'.format(x/100.) for x in vals])
vals = ax[0].get_yticks()
ax[0].set_yticklabels(['{:,.0%}'.format(x/100.) for x in vals])

#handles, labels = ax[0].get_legend_handles_labels()
#ax[1].legend(loc='center left', bbox_to_anchor=(1, 0.5),prop={"size":25})

ynames = ['train_upper_loss','test_upper_loss_all']
ylim = [0,2.]
gen_list = make_gens(list_config_dicts,ynames,group_keys)
fig, ax = plt.subplots(num_y,num_x, figsize=(6*num_x,4*num_y))
for i,(gen,yname) in enumerate(zip(gen_list,ynames)):
    plot_from_config(ax[i],
                 gen,
                 color_dict,
                 labels_dict,
                 linestyles_dict,
                 xscale='linear',
                 yscale = 'linear',
                 ylabel=yname,
                 xlabel= 'Epochs',
                 title= yname ,
                 fontsize=30,
                 xlim=xlim,
                 ylim= None,
                 ticks_fontsize=20,
                 lw=lw,
                 with_legend=False)



handles, labels = ax[0].get_legend_handles_labels()
ax[1].legend(loc='center left', bbox_to_anchor=(1, 0.5),prop={"size":25})

ynames = ['upper_grad_norm','dual_var_norm']
ylim = [0,1.]
gen_list = make_gens(list_config_dicts,ynames,group_keys)
fig, ax = plt.subplots(num_y,num_x, figsize=(6*num_x,4*num_y))
for i,(gen,yname) in enumerate(zip(gen_list,ynames)):
    plot_from_config(ax[i],
                 gen,
                 color_dict,
                 labels_dict,
                 linestyles_dict,
                 xscale='linear',
                 yscale = 'linear',
                 ylabel=yname,
                 xlabel= 'Epochs',
                 title= yname ,
                 fontsize=30,
                 xlim=xlim,
                 ylim= None,
                 ticks_fontsize=20,
                 lw=lw,
                 with_legend=False)



handles, labels = ax[0].get_legend_handles_labels()
ax[1].legend(loc='center left', bbox_to_anchor=(1, 0.5),prop={"size":25})



plt.tight_layout()





fig_name = 'multitask_cifar100_total'
save(fig_name)
# Out:
# /tmp/ipykernel_11510/2217834120.py:35: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[1].set_yticklabels(['{:,.0%}'.format(x/100.) for x in vals])
# /tmp/ipykernel_11510/2217834120.py:37: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_yticklabels(['{:,.0%}'.format(x/100.) for x in vals])

# %%
ynames = ['train_upper_acc','test_upper_acc_all']
ynames = ['train_upper_loss','test_upper_loss_all']
gen_list = make_gens(list_config_dicts,ynames,group_keys)
gen_list[1][0]['y'][-1]

i = np.argmin(gen_list[0][0]['y'], axis=0)
i
# Out:
# 200

# %%
log_name = 'distillation_cifar10'
out_dir = '../data/outputs'
reader = load_method(log_name,out_dir)

query = {'training.lower.model.name': ['torchvision.models.resnet18'],
        }

out = reader.search(query)
#color_dict, labels_dict, linestyles_dict,colors = make_plot_dicts(out)
len(out)
# Out:
# 39

# %%
val_keys = ['train_upper_loss','train_upper_acc','test_upper_loss','test_upper_acc']
failed_exps = []
for i,p in enumerate(out):
    try:
        add_res_to_data(p, val_keys, mode='last')
    except:
        failed_exps.append(i)

out = [p  for i,p in enumerate(out) if i not in  failed_exps]


group_keys = [('selection','correction')]

#group_keys = [('selection','optimizer','lr')]
#variable_keys = [('data','b_size')]
variable_keys = [('training','total_epoch')]
variable_keys = [('training','lower','model','name')]

#variable_keys = [('solver','inner_forward','n_iter')]

value_keys = [('results','train_upper_loss'), ('results','test_upper_loss'),('results','train_upper_acc'),('results','test_upper_acc')]
apply_func = [safeargmin,safeargmin, safeargmax,safeargmax]
aggregate_dict = aggregate_res_dict(out,group_keys, variable_keys, value_keys)
reduced_dict = reduce_res_dict(aggregate_dict, apply_func,variable_keys,sort=True, is_index=True)
list_config_dicts = reduced_dict_to_list_dicts(reduced_dict, 0, 'index_results_'+value_keys[2][1])
methods = reduced_dict.keys()
key_name = '-'.join([el[-1] for el in group_keys])+':'

color_dict, labels_dict, linestyles_dict,colors = make_plot_dicts(methods,key_name)
# Out:
# [Errno 2] No such file or directory: '/home/marbel/Documents/projects/BGS-opt/data/outputs/distillation_cifar10/23/metrics.json'
# [Errno 2] No such file or directory: '/home/marbel/Documents/projects/BGS-opt/data/outputs/distillation_cifar10/24/metrics.json'
# [Errno 2] No such file or directory: '/home/marbel/Documents/projects/BGS-opt/data/outputs/distillation_cifar10/25/metrics.json'
# [Errno 2] No such file or directory: '/home/marbel/Documents/projects/BGS-opt/data/outputs/distillation_cifar10/26/metrics.json'
# [Errno 2] No such file or directory: '/home/marbel/Documents/projects/BGS-opt/data/outputs/distillation_cifar10/30/metrics.json'

# %%
for i, o in enumerate(out):
    if o['logs']['log_id']==65:
        print(i)
#out[24]
#reduced_dict['False']
#aggregate_dict['False']
# Out:
# 24

# %%
num_x =2
num_y = 1
avg_time_dict = None
xlabel = ''
ylabel = ''
title  = ''
xlim=[0,40000]
ylim = [20,80.]
xlabel = 'Epochs'
lw = 3.
ynames = ['train_upper_acc','test_upper_acc']
title_names = ['Training accuracy vs time','Test accuracy vs time']
y_names = ['Accuracy','Accuracy']
gen_list = make_gens(list_config_dicts,ynames,group_keys,xname='time')
fig, ax = plt.subplots(num_y,num_x, figsize=(8*num_x,5*num_y))
for i,(gen,title_name,y_name) in enumerate(zip(gen_list,title_names,y_names)):
    plot_from_config(ax[i],
                 gen,
                 color_dict,
                 labels_dict,
                 linestyles_dict,
                 xscale='linear',
                 yscale = 'linear',
                 ylabel=y_name,
                 xlabel= 'Time (s)',
                 title= title_name ,
                 fontsize=25,
                 xlim=xlim,
                 ylim= None,
                 ticks_fontsize=20,
                 lw=lw,
                 with_legend=False)



vals = ax[1].get_yticks()
ax[1].set_yticklabels(['{:,.0%}'.format(x/100.) for x in vals])
vals = ax[0].get_yticks()
ax[0].set_yticklabels(['{:,.0%}'.format(x/100.) for x in vals])

handles, labels = ax[0].get_legend_handles_labels()
ax[1].legend(loc='center right', bbox_to_anchor=(1, 0.2),prop={"size":20})



plt.tight_layout()





fig_name = 'distillation_cifar10'
save(fig_name)
# Out:
# /tmp/ipykernel_11510/1526184922.py:37: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[1].set_yticklabels(['{:,.0%}'.format(x/100.) for x in vals])
# /tmp/ipykernel_11510/1526184922.py:39: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_yticklabels(['{:,.0%}'.format(x/100.) for x in vals])

# %%
max(gen_list[0][1]['y'])
# Out:
# 54.34305205637095

# %%
log_name = 'toy_sin'
out_dir = '../data/outputs'
reader = load_method(log_name,out_dir)

query = {'training.lower.objective.with_sin': [True],
         'selection.warm_start_iter':[0]}
out = reader.search(query)


query = {'training.lower.objective.with_sin': [True],
         'selection.warm_start_iter':[1],
        'selection.correction':[True]}
#out+=reader.search(query)


#color_dict, labels_dict, linestyles_dict,colors = make_plot_dicts(out)
len(out)
# Out:
# 9

# %%
val_keys = ['train_upper_loss','test_upper_loss']
failed_exps = []
for i,p in enumerate(out):
    add_res_to_data(p, val_keys, mode='last')
#        failed_exps.append(i)

out = [p  for i,p in enumerate(out) if i not in  failed_exps]


group_keys = [('selection','correction'), ('selection', 'warm_start_iter'),('selection', 'unrolled_iter'), ]

#group_keys = [('selection','optimizer','lr')]
#variable_keys = [('data','b_size')]
variable_keys = [('training','total_epoch')]
variable_keys = [('training','lower','model','name')]

#variable_keys = [('solver','inner_forward','n_iter')]

value_keys = [('results','train_upper_loss'), ('results','test_upper_loss')]
apply_func = [safeargmin,safeargmin]
aggregate_dict = aggregate_res_dict(out,group_keys, variable_keys, value_keys)
reduced_dict = reduce_res_dict(aggregate_dict, apply_func,variable_keys,sort=True, is_index=True)
list_config_dicts = reduced_dict_to_list_dicts(reduced_dict, 0, 'index_results_'+value_keys[1][1])
#methods = reduced_dict.keys()
#key_name = '-'.join([el[-1] for el in group_keys])+':'

#color_dict, labels_dict, linestyles_dict,colors = make_plot_dicts(methods,key_name)

# %%
aggregate_dict['True_0_10']['examples.toy.models.Identity']
# Out:
# {'values': {'results_train_upper_loss': [-3.589782863855362e-05,
#    1.5428289771080017e-05,
#    3.087799996137619e-05],
#   'results_test_upper_loss': [4.042554155053999e-14,
#    8.12670264184239e-17,
#    3.233259324343641e-16]},
#  'vars': {'training_lower_model_name': 'examples.toy.models.Identity'},
#  'refs': {'results_train_upper_loss': [{'cluster': {'cleanup': 'source gpu_setVisibleDevices.sh',
#      'cmd': 'oarsub -S',
#      'conda_env': 'default',
#      'directive': '#OAR',
#      'engine': 'OAR',
#      'launchers': 'default',
#      'name': 'thoth',
#      'shell': {'bin_path': '/bin/bash', 'config_path': '~/.bashrc'},
#      'user': 'marbel'},
#     'launcher': {'besteffort': False,
#      'cmd': 'run.py',
#      'cpus': 1,
#      'filename': 'default.sh',
#      'gpumem': None,
#      'gpumodel': None,
#      'hours': 12,
#      'idempotent': False,
#      'name': 'default',
#      'nodes': 1},
#     'logs': {'log_dir': 'data/outputs',
#      'log_id': 1,
#      'log_name': 'toy_sin',
#      'log_to_file': False,
#      'path': '/home/marbel/Documents/projects/BGS-opt/data/outputs/toy_sin/1/metrics.json'},
#     'selection': {'add_correction': True,
#      'compute_latest_correction': True,
#      'correction': True,
#      'dual_var_warm_start': True,
#      'linear_op': {'compute_new_grad': True,
#       'name': 'core.selection.HessianOp',
#       'stochastic': True,
#       'use_new_input': True},
#      'linear_solver': {'lr': 0.9,
#       'n_iter': 10,
#       'name': 'core.linear_solvers.GD'},
#      'name': 'BGS',
#      'optimizer': {'lr': 0.9, 'momentum': 0.0, 'name': 'TorchOpt.sgd'},
#      'scheduler': {'T_max': 2000,
#       'name': 'torch.optim.lr_scheduler.CosineAnnealingLR',
#       'use_scheduler': False},
#      'unrolled_iter': 10,
#      'warm_start_iter': 0},
#     'system': {'dataparallel': False,
#      'date': '01/08/2022',
#      'device': -2,
#      'dtype': 64,
#      'experimentalist': True,
#      'hostname': 'gpuhost22',
#      'num_workers': 1,
#      'process_id': 56637,
#      'seed': {'numpy': 0, 'torch': 0},
#      'slurm_id': '',
#      'time': '15:52:03'},
#     'training': {'loader': {'b_size': 1, 'eval_b_size': 1},
#      'lower': {'model': {'dim': 1000, 'name': 'examples.toy.models.Identity'},
#       'objective': {'cond': 10,
#        'name': 'examples.toy.models.QuadyLinx',
#        'with_sin': True}},
#      'metrics': {'disp_freq': 10,
#       'epoch_eval': True,
#       'eval_test': True,
#       'freq_lower_cond': 5000,
#       'log_artefacts_freq': 200,
#       'log_artifacts': True,
#       'log_lower_cond': False,
#       'max_lower_iter': 1,
#       'max_upper_iter': 1,
#       'name': 'value'},
#      'resume': True,
#      'total_epoch': 2000,
#      'trainer_name': 'examples.toy.trainer.Trainer',
#      'upper': {'clip': False,
#       'max_norm': 1.0,
#       'model': {'dim': 2000,
#        'name': 'examples.toy.models.Identity',
#        'path': ''},
#       'objective': {'cond': 10, 'name': 'examples.toy.models.QuadyLinx'},
#       'optimizer': {'lr': 1.0, 'name': 'torch.optim.SGD', 'weight_decay': 0.0},
#       'scheduler': {'name': 'torch.optim.lr_scheduler.ReduceLROnPlateau',
#        'patience': 1,
#        'use_scheduler': False}}},
#     'results': {'train_upper_loss': -3.589782863855362e-05,
#      'test_upper_loss': 4.042554155053999e-14}},
#    {'cluster': {'cleanup': 'source gpu_setVisibleDevices.sh',
#      'cmd': 'oarsub -S',
#      'conda_env': 'default',
#      'directive': '#OAR',
#      'engine': 'OAR',
#      'launchers': 'default',
#      'name': 'thoth',
#      'shell': {'bin_path': '/bin/bash', 'config_path': '~/.bashrc'},
#      'user': 'marbel'},
#     'launcher': {'besteffort': False,
#      'cmd': 'run.py',
#      'cpus': 1,
#      'filename': 'default.sh',
#      'gpumem': None,
#      'gpumodel': None,
#      'hours': 12,
#      'idempotent': False,
#      'name': 'default',
#      'nodes': 1},
#     'logs': {'log_dir': 'data/outputs',
#      'log_id': 20,
#      'log_name': 'toy_sin',
#      'log_to_file': False,
#      'path': '/home/marbel/Documents/projects/BGS-opt/data/outputs/toy_sin/20/metrics.json'},
#     'selection': {'add_correction': True,
#      'compute_latest_correction': True,
#      'correction': True,
#      'dual_var_warm_start': True,
#      'linear_op': {'compute_new_grad': True,
#       'name': 'core.selection.HessianOp',
#       'stochastic': True,
#       'use_new_input': True},
#      'linear_solver': {'lr': 0.9,
#       'n_iter': 1,
#       'name': 'core.linear_solvers.GD'},
#      'name': 'BGS',
#      'optimizer': {'lr': 0.9, 'momentum': 0.0, 'name': 'TorchOpt.sgd'},
#      'scheduler': {'T_max': 2000,
#       'name': 'torch.optim.lr_scheduler.CosineAnnealingLR',
#       'use_scheduler': False},
#      'unrolled_iter': 10,
#      'warm_start_iter': 0},
#     'system': {'dataparallel': False,
#      'date': '01/08/2022',
#      'device': -2,
#      'dtype': 64,
#      'experimentalist': True,
#      'hostname': 'gpuhost19',
#      'num_workers': 1,
#      'process_id': 77399,
#      'seed': {'numpy': 0, 'torch': 0},
#      'slurm_id': '',
#      'time': '17:05:30'},
#     'training': {'loader': {'b_size': 1, 'eval_b_size': 1},
#      'lower': {'model': {'dim': 1000, 'name': 'examples.toy.models.Identity'},
#       'objective': {'cond': 10,
#        'name': 'examples.toy.models.QuadyLinx',
#        'with_sin': True}},
#      'metrics': {'disp_freq': 10,
#       'epoch_eval': True,
#       'eval_test': True,
#       'freq_lower_cond': 5000,
#       'log_artefacts_freq': 200,
#       'log_artifacts': True,
#       'log_lower_cond': False,
#       'max_lower_iter': 1,
#       'max_upper_iter': 1,
#       'name': 'value'},
#      'resume': True,
#      'total_epoch': 2000,
#      'trainer_name': 'examples.toy.trainer.Trainer',
#      'upper': {'clip': False,
#       'max_norm': 1.0,
#       'model': {'dim': 2000,
#        'name': 'examples.toy.models.Identity',
#        'path': ''},
#       'objective': {'cond': 10, 'name': 'examples.toy.models.QuadyLinx'},
#       'optimizer': {'lr': 1.0, 'name': 'torch.optim.SGD', 'weight_decay': 0.0},
#       'scheduler': {'name': 'torch.optim.lr_scheduler.ReduceLROnPlateau',
#        'patience': 1,
#        'use_scheduler': False}}},
#     'results': {'train_upper_loss': 1.5428289771080017e-05,
#      'test_upper_loss': 8.12670264184239e-17}},
#    {'cluster': {'cleanup': 'source gpu_setVisibleDevices.sh',
#      'cmd': 'oarsub -S',
#      'conda_env': 'default',
#      'directive': '#OAR',
#      'engine': 'OAR',
#      'launchers': 'default',
#      'name': 'thoth',
#      'shell': {'bin_path': '/bin/bash', 'config_path': '~/.bashrc'},
#      'user': 'marbel'},
#     'launcher': {'besteffort': False,
#      'cmd': 'run.py',
#      'cpus': 1,
#      'filename': 'default.sh',
#      'gpumem': None,
#      'gpumodel': None,
#      'hours': 12,
#      'idempotent': False,
#      'name': 'default',
#      'nodes': 1},
#     'logs': {'log_dir': 'data/outputs',
#      'log_id': 27,
#      'log_name': 'toy_sin',
#      'log_to_file': False,
#      'path': '/home/marbel/Documents/projects/BGS-opt/data/outputs/toy_sin/27/metrics.json'},
#     'selection': {'add_correction': True,
#      'compute_latest_correction': True,
#      'correction': True,
#      'dual_var_warm_start': True,
#      'linear_op': {'compute_new_grad': True,
#       'name': 'core.selection.HessianOp',
#       'stochastic': True,
#       'use_new_input': True},
#      'linear_solver': {'lr': 0.9,
#       'n_iter': 1,
#       'name': 'core.linear_solvers.GD'},
#      'name': 'BGS',
#      'optimizer': {'lr': 0.9, 'momentum': 0.0, 'name': 'TorchOpt.sgd'},
#      'scheduler': {'T_max': 4000,
#       'name': 'torch.optim.lr_scheduler.CosineAnnealingLR',
#       'use_scheduler': False},
#      'unrolled_iter': 10,
#      'warm_start_iter': 0},
#     'system': {'dataparallel': False,
#      'date': '01/08/2022',
#      'device': -2,
#      'dtype': 64,
#      'experimentalist': True,
#      'hostname': 'gpuhost11',
#      'num_workers': 1,
#      'process_id': 11484,
#      'seed': {'numpy': 0, 'torch': 0},
#      'slurm_id': '',
#      'time': '17:07:17'},
#     'training': {'loader': {'b_size': 1, 'eval_b_size': 1},
#      'lower': {'model': {'dim': 1000, 'name': 'examples.toy.models.Identity'},
#       'objective': {'cond': 10,
#        'name': 'examples.toy.models.QuadyLinx',
#        'with_sin': True}},
#      'metrics': {'disp_freq': 10,
#       'epoch_eval': True,
#       'eval_test': True,
#       'freq_lower_cond': 5000,
#       'log_artefacts_freq': 200,
#       'log_artifacts': True,
#       'log_lower_cond': False,
#       'max_lower_iter': 1,
#       'max_upper_iter': 1,
#       'name': 'value'},
#      'resume': True,
#      'total_epoch': 4000,
#      'trainer_name': 'examples.toy.trainer.Trainer',
#      'upper': {'clip': False,
#       'max_norm': 1.0,
#       'model': {'dim': 2000,
#        'name': 'examples.toy.models.Identity',
#        'path': ''},
#       'objective': {'cond': 10, 'name': 'examples.toy.models.QuadyLinx'},
#       'optimizer': {'lr': 1.0, 'name': 'torch.optim.SGD', 'weight_decay': 0.0},
#       'scheduler': {'name': 'torch.optim.lr_scheduler.ReduceLROnPlateau',
#        'patience': 1,
#        'use_scheduler': False}}},
#     'results': {'train_upper_loss': 3.087799996137619e-05,
#      'test_upper_loss': 3.233259324343641e-16}}],
#   'results_test_upper_loss': [{'cluster': {'cleanup': 'source gpu_setVisibleDevices.sh',
#      'cmd': 'oarsub -S',
#      'conda_env': 'default',
#      'directive': '#OAR',
#      'engine': 'OAR',
#      'launchers': 'default',
#      'name': 'thoth',
#      'shell': {'bin_path': '/bin/bash', 'config_path': '~/.bashrc'},
#      'user': 'marbel'},
#     'launcher': {'besteffort': False,
#      'cmd': 'run.py',
#      'cpus': 1,
#      'filename': 'default.sh',
#      'gpumem': None,
#      'gpumodel': None,
#      'hours': 12,
#      'idempotent': False,
#      'name': 'default',
#      'nodes': 1},
#     'logs': {'log_dir': 'data/outputs',
#      'log_id': 1,
#      'log_name': 'toy_sin',
#      'log_to_file': False,
#      'path': '/home/marbel/Documents/projects/BGS-opt/data/outputs/toy_sin/1/metrics.json'},
#     'selection': {'add_correction': True,
#      'compute_latest_correction': True,
#      'correction': True,
#      'dual_var_warm_start': True,
#      'linear_op': {'compute_new_grad': True,
#       'name': 'core.selection.HessianOp',
#       'stochastic': True,
#       'use_new_input': True},
#      'linear_solver': {'lr': 0.9,
#       'n_iter': 10,
#       'name': 'core.linear_solvers.GD'},
#      'name': 'BGS',
#      'optimizer': {'lr': 0.9, 'momentum': 0.0, 'name': 'TorchOpt.sgd'},
#      'scheduler': {'T_max': 2000,
#       'name': 'torch.optim.lr_scheduler.CosineAnnealingLR',
#       'use_scheduler': False},
#      'unrolled_iter': 10,
#      'warm_start_iter': 0},
#     'system': {'dataparallel': False,
#      'date': '01/08/2022',
#      'device': -2,
#      'dtype': 64,
#      'experimentalist': True,
#      'hostname': 'gpuhost22',
#      'num_workers': 1,
#      'process_id': 56637,
#      'seed': {'numpy': 0, 'torch': 0},
#      'slurm_id': '',
#      'time': '15:52:03'},
#     'training': {'loader': {'b_size': 1, 'eval_b_size': 1},
#      'lower': {'model': {'dim': 1000, 'name': 'examples.toy.models.Identity'},
#       'objective': {'cond': 10,
#        'name': 'examples.toy.models.QuadyLinx',
#        'with_sin': True}},
#      'metrics': {'disp_freq': 10,
#       'epoch_eval': True,
#       'eval_test': True,
#       'freq_lower_cond': 5000,
#       'log_artefacts_freq': 200,
#       'log_artifacts': True,
#       'log_lower_cond': False,
#       'max_lower_iter': 1,
#       'max_upper_iter': 1,
#       'name': 'value'},
#      'resume': True,
#      'total_epoch': 2000,
#      'trainer_name': 'examples.toy.trainer.Trainer',
#      'upper': {'clip': False,
#       'max_norm': 1.0,
#       'model': {'dim': 2000,
#        'name': 'examples.toy.models.Identity',
#        'path': ''},
#       'objective': {'cond': 10, 'name': 'examples.toy.models.QuadyLinx'},
#       'optimizer': {'lr': 1.0, 'name': 'torch.optim.SGD', 'weight_decay': 0.0},
#       'scheduler': {'name': 'torch.optim.lr_scheduler.ReduceLROnPlateau',
#        'patience': 1,
#        'use_scheduler': False}}},
#     'results': {'train_upper_loss': -3.589782863855362e-05,
#      'test_upper_loss': 4.042554155053999e-14}},
#    {'cluster': {'cleanup': 'source gpu_setVisibleDevices.sh',
#      'cmd': 'oarsub -S',
#      'conda_env': 'default',
#      'directive': '#OAR',
#      'engine': 'OAR',
#      'launchers': 'default',
#      'name': 'thoth',
#      'shell': {'bin_path': '/bin/bash', 'config_path': '~/.bashrc'},
#      'user': 'marbel'},
#     'launcher': {'besteffort': False,
#      'cmd': 'run.py',
#      'cpus': 1,
#      'filename': 'default.sh',
#      'gpumem': None,
#      'gpumodel': None,
#      'hours': 12,
#      'idempotent': False,
#      'name': 'default',
#      'nodes': 1},
#     'logs': {'log_dir': 'data/outputs',
#      'log_id': 20,
#      'log_name': 'toy_sin',
#      'log_to_file': False,
#      'path': '/home/marbel/Documents/projects/BGS-opt/data/outputs/toy_sin/20/metrics.json'},
#     'selection': {'add_correction': True,
#      'compute_latest_correction': True,
#      'correction': True,
#      'dual_var_warm_start': True,
#      'linear_op': {'compute_new_grad': True,
#       'name': 'core.selection.HessianOp',
#       'stochastic': True,
#       'use_new_input': True},
#      'linear_solver': {'lr': 0.9,
#       'n_iter': 1,
#       'name': 'core.linear_solvers.GD'},
#      'name': 'BGS',
#      'optimizer': {'lr': 0.9, 'momentum': 0.0, 'name': 'TorchOpt.sgd'},
#      'scheduler': {'T_max': 2000,
#       'name': 'torch.optim.lr_scheduler.CosineAnnealingLR',
#       'use_scheduler': False},
#      'unrolled_iter': 10,
#      'warm_start_iter': 0},
#     'system': {'dataparallel': False,
#      'date': '01/08/2022',
#      'device': -2,
#      'dtype': 64,
#      'experimentalist': True,
#      'hostname': 'gpuhost19',
#      'num_workers': 1,
#      'process_id': 77399,
#      'seed': {'numpy': 0, 'torch': 0},
#      'slurm_id': '',
#      'time': '17:05:30'},
#     'training': {'loader': {'b_size': 1, 'eval_b_size': 1},
#      'lower': {'model': {'dim': 1000, 'name': 'examples.toy.models.Identity'},
#       'objective': {'cond': 10,
#        'name': 'examples.toy.models.QuadyLinx',
#        'with_sin': True}},
#      'metrics': {'disp_freq': 10,
#       'epoch_eval': True,
#       'eval_test': True,
#       'freq_lower_cond': 5000,
#       'log_artefacts_freq': 200,
#       'log_artifacts': True,
#       'log_lower_cond': False,
#       'max_lower_iter': 1,
#       'max_upper_iter': 1,
#       'name': 'value'},
#      'resume': True,
#      'total_epoch': 2000,
#      'trainer_name': 'examples.toy.trainer.Trainer',
#      'upper': {'clip': False,
#       'max_norm': 1.0,
#       'model': {'dim': 2000,
#        'name': 'examples.toy.models.Identity',
#        'path': ''},
#       'objective': {'cond': 10, 'name': 'examples.toy.models.QuadyLinx'},
#       'optimizer': {'lr': 1.0, 'name': 'torch.optim.SGD', 'weight_decay': 0.0},
#       'scheduler': {'name': 'torch.optim.lr_scheduler.ReduceLROnPlateau',
#        'patience': 1,
#        'use_scheduler': False}}},
#     'results': {'train_upper_loss': 1.5428289771080017e-05,
#      'test_upper_loss': 8.12670264184239e-17}},
#    {'cluster': {'cleanup': 'source gpu_setVisibleDevices.sh',
#      'cmd': 'oarsub -S',
#      'conda_env': 'default',
#      'directive': '#OAR',
#      'engine': 'OAR',
#      'launchers': 'default',
#      'name': 'thoth',
#      'shell': {'bin_path': '/bin/bash', 'config_path': '~/.bashrc'},
#      'user': 'marbel'},
#     'launcher': {'besteffort': False,
#      'cmd': 'run.py',
#      'cpus': 1,
#      'filename': 'default.sh',
#      'gpumem': None,
#      'gpumodel': None,
#      'hours': 12,
#      'idempotent': False,
#      'name': 'default',
#      'nodes': 1},
#     'logs': {'log_dir': 'data/outputs',
#      'log_id': 27,
#      'log_name': 'toy_sin',
#      'log_to_file': False,
#      'path': '/home/marbel/Documents/projects/BGS-opt/data/outputs/toy_sin/27/metrics.json'},
#     'selection': {'add_correction': True,
#      'compute_latest_correction': True,
#      'correction': True,
#      'dual_var_warm_start': True,
#      'linear_op': {'compute_new_grad': True,
#       'name': 'core.selection.HessianOp',
#       'stochastic': True,
#       'use_new_input': True},
#      'linear_solver': {'lr': 0.9,
#       'n_iter': 1,
#       'name': 'core.linear_solvers.GD'},
#      'name': 'BGS',
#      'optimizer': {'lr': 0.9, 'momentum': 0.0, 'name': 'TorchOpt.sgd'},
#      'scheduler': {'T_max': 4000,
#       'name': 'torch.optim.lr_scheduler.CosineAnnealingLR',
#       'use_scheduler': False},
#      'unrolled_iter': 10,
#      'warm_start_iter': 0},
#     'system': {'dataparallel': False,
#      'date': '01/08/2022',
#      'device': -2,
#      'dtype': 64,
#      'experimentalist': True,
#      'hostname': 'gpuhost11',
#      'num_workers': 1,
#      'process_id': 11484,
#      'seed': {'numpy': 0, 'torch': 0},
#      'slurm_id': '',
#      'time': '17:07:17'},
#     'training': {'loader': {'b_size': 1, 'eval_b_size': 1},
#      'lower': {'model': {'dim': 1000, 'name': 'examples.toy.models.Identity'},
#       'objective': {'cond': 10,
#        'name': 'examples.toy.models.QuadyLinx',
#        'with_sin': True}},
#      'metrics': {'disp_freq': 10,
#       'epoch_eval': True,
#       'eval_test': True,
#       'freq_lower_cond': 5000,
#       'log_artefacts_freq': 200,
#       'log_artifacts': True,
#       'log_lower_cond': False,
#       'max_lower_iter': 1,
#       'max_upper_iter': 1,
#       'name': 'value'},
#      'resume': True,
#      'total_epoch': 4000,
#      'trainer_name': 'examples.toy.trainer.Trainer',
#      'upper': {'clip': False,
#       'max_norm': 1.0,
#       'model': {'dim': 2000,
#        'name': 'examples.toy.models.Identity',
#        'path': ''},
#       'objective': {'cond': 10, 'name': 'examples.toy.models.QuadyLinx'},
#       'optimizer': {'lr': 1.0, 'name': 'torch.optim.SGD', 'weight_decay': 0.0},
#       'scheduler': {'name': 'torch.optim.lr_scheduler.ReduceLROnPlateau',
#        'patience': 1,
#        'use_scheduler': False}}},
#     'results': {'train_upper_loss': 3.087799996137619e-05,
#      'test_upper_loss': 3.233259324343641e-16}}]}}

# %%
labels_dict, linestyles_dict
# Out:
# ({'True_0_10': 'correction-warm_start_iter-unrolled_iter: True_0_10',
#   'False_0_100': 'correction-warm_start_iter-unrolled_iter: False_0_100',
#   'False_0_1000': 'correction-warm_start_iter-unrolled_iter: False_0_1000',
#   'False_0_1': 'correction-warm_start_iter-unrolled_iter: False_0_1',
#   'True_0_1': 'correction-warm_start_iter-unrolled_iter: True_0_1',
#   'False_0_10': 'correction-warm_start_iter-unrolled_iter: False_0_10'},
#  {'True_0_10': '-',
#   'False_0_100': '-',
#   'False_0_1000': '-',
#   'False_0_1': '-',
#   'True_0_1': '-',
#   'False_0_10': '-'})

# %%
labels_dict = {'True': 'with correction', 'False': 'without correction'}

labels_dict = {'True_0_10': 'With Corr, $N{=}10$',
  'False_0_10': 'Without Corr, $N=10$',
  'True_0_1': 'With Corr, $N=1$',
  'False_0_1': 'Without Corr, $N=1$',
  'True_1_0': 'With Corr, $M=1$',
   'False_0_100': 'Without Corr, $N=100$',
  'False_0_1000': 'Without Corr, $N=1000$',}

linestyles_dict= {'True_0_10': '-',
  'False_0_10': '-.',
  'True_0_1': '-',
  'False_0_1': '-.',
  'True_1_0': '-',
  'False_0_100': '-.',
  'False_0_1000': '-.',}


#linestyles_dict

# %%
#gen_list[0][1]['key']

# %%
num_x =2
num_y = 1
avg_time_dict = None
xlabel = ''
ylabel = ''
title  = ''
xlim= None#[0,300]
ylim = [20,80.]
xlabel = 'Epochs'
lw = 3.
ynames = ['test_upper_loss','upper_grad_norm']
title_name = ['UL loss vs time','UL gradient norm vs time']
y_name = ['UL loss','UL gradient']
gen_list = make_gens(list_config_dicts,ynames,group_keys,xname='time')
fig, ax = plt.subplots(num_y,num_x, figsize=(10*num_x,5*num_y))
for i,(gen,titlename,yname) in enumerate(zip(gen_list,title_name,y_name)):
    plot_from_config(ax[i],
                 gen,
                 color_dict,
                 labels_dict,
                 linestyles_dict,
                 xscale='log',
                 yscale = 'log',
                 ylabel=yname,
                 xlabel= 'Time (s)',
                 title= titlename ,
                 fontsize=20,
                 xlim=xlim,
                 ylim= None,
                 ticks_fontsize=20,
                 lw=lw,
                 with_legend=False)



vals = ax[1].get_yticks()
#ax[1].set_yticklabels(['{:,.0%}'.format(x/100.) for x in vals])
vals = ax[0].get_yticks()
#ax[0].set_yticklabels(['{:,.0%}'.format(x/100.) for x in vals])

handles, labels = ax[0].get_legend_handles_labels()
labels, handles = zip(*sorted(zip(labels, handles)))
ax[1].legend(handles, labels, loc='center left', bbox_to_anchor=(1, 0.5),prop={"size":15})

#ax[1].legend(loc='center right', bbox_to_anchor=(1, 0.2),prop={"size":15})


plt.tight_layout()





fig_name = 'toy_sin'
save(fig_name)

# %%
log_name = 'toy_sin'
out_dir = '../data/outputs'
reader = load_method(log_name,out_dir)

query = {'training.lower.objective.with_sin': [False],
         'selection.warm_start_iter':[0]}
out = reader.search(query)


query = {'training.lower.objective.with_sin': [False],
         'selection.warm_start_iter':[1],
        'selection.correction':[True]}
#out+=reader.search(query)


#color_dict, labels_dict, linestyles_dict,colors = make_plot_dicts(out)
len(out)
# Out:
# 9

# %%
val_keys = ['train_upper_loss','test_upper_loss']
failed_exps = []
for i,p in enumerate(out):
    add_res_to_data(p, val_keys, mode='last')
#        failed_exps.append(i)

out = [p  for i,p in enumerate(out) if i not in  failed_exps]


group_keys = [('selection','correction'), ('selection', 'warm_start_iter'),('selection', 'unrolled_iter'), ]

#group_keys = [('selection','optimizer','lr')]
#variable_keys = [('data','b_size')]
variable_keys = [('training','total_epoch')]
variable_keys = [('training','lower','model','name')]

#variable_keys = [('solver','inner_forward','n_iter')]

value_keys = [('results','train_upper_loss'), ('results','test_upper_loss')]
apply_func = [safeargmin,safeargmin]
aggregate_dict = aggregate_res_dict(out,group_keys, variable_keys, value_keys)
reduced_dict = reduce_res_dict(aggregate_dict, apply_func,variable_keys,sort=True, is_index=True)
list_config_dicts = reduced_dict_to_list_dicts(reduced_dict, 0, 'index_results_'+value_keys[1][1])
methods = reduced_dict.keys()
key_name = '-'.join([el[-1] for el in group_keys])+':'

_, labels_dict, linestyles_dict,_ = make_plot_dicts(methods,key_name)

# %%
labels_dict
# Out:
# {'False_0_100': 'correction-warm_start_iter-unrolled_iter: False_0_100',
#  'False_0_1000': 'correction-warm_start_iter-unrolled_iter: False_0_1000',
#  'False_0_1': 'correction-warm_start_iter-unrolled_iter: False_0_1',
#  'True_0_1': 'correction-warm_start_iter-unrolled_iter: True_0_1',
#  'True_0_10': 'correction-warm_start_iter-unrolled_iter: True_0_10',
#  'False_0_10': 'correction-warm_start_iter-unrolled_iter: False_0_10'}

# %%
labels_dict = {'True': 'with correction', 'False': 'without correction'}

labels_dict = {'True_0_10': 'With Corr, $T{=}10$',
  'False_0_10': 'Without Corr, $T=10$',
  'True_0_1': 'With Corr, $T=1$',
  'False_0_1': 'Without Corr, $T=1$',
  'True_1_0': 'With Corr, $M=1$',
   'False_0_100': 'Without Corr, $T=100$',
  'False_0_1000': 'Without Corr, $T=1000$',}

linestyles_dict= {'True_0_10': '-',
  'False_0_10': '-.',
  'True_0_1': '-',
  'False_0_1': '-.',
  'True_1_0': '-',
  'False_0_100': '-.',
  'False_0_1000': '-.',}


#linestyles_dict

# %%
num_x =2
num_y = 1
avg_time_dict = None
xlabel = ''
ylabel = ''
title  = ''
xlim= None#[0,300]
ylim = [20,80.]
xlabel = 'Epochs'
lw = 3.
ynames = ['test_upper_loss','upper_grad_norm']
title_name = ['Distance to $x^{\star}$ vs time','UL gradient norm vs time']
y_name = ['$\Vert x_k-x^{\star}\Vert^2_{A_f}$','UL gradient']
gen_list = make_gens(list_config_dicts,ynames,group_keys,xname='time')
fig, ax = plt.subplots(num_y,num_x, figsize=(10*num_x,5*num_y))
for i,(gen,titlename,yname) in enumerate(zip(gen_list,title_name,y_name)):
    plot_from_config(ax[i],
                 gen,
                 color_dict,
                 labels_dict,
                 linestyles_dict,
                 xscale='log',
                 yscale = 'log',
                 ylabel=yname,
                 xlabel= 'Time (s)',
                 title= titlename ,
                 fontsize=25,
                 xlim=xlim,
                 ylim= None,
                 ticks_fontsize=25,
                 lw=lw,
                 with_legend=False)



vals = ax[1].get_yticks()
#ax[1].set_yticklabels(['{:,.0%}'.format(x/100.) for x in vals])
vals = ax[0].get_yticks()
#ax[0].set_yticklabels(['{:,.0%}'.format(x/100.) for x in vals])

handles, labels = ax[0].get_legend_handles_labels()
labels, handles = zip(*sorted(zip(labels, handles)))
ax[1].legend(handles, labels, loc='center left', bbox_to_anchor=(1, 0.5),prop={"size":25})

#ax[1].legend(loc='center right', bbox_to_anchor=(1, 0.2),prop={"size":15})


plt.tight_layout()





fig_name = 'toy_quad'
save(fig_name)

# %%
b =.1 
x_0 = np.linspace(0,b+10,100000)
y = (2*x_0-10)**2
y= x_0
a=10
c =1
x = np.cos(a*np.exp(-(y-b)))*y
#x = -np.sin(a*y) + y
u = a*np.exp(-(y-b))

#x = np.sqrt((y-10.)**2+ 1.)

plt.plot(x_0,x)

#plt.plot(x_0,z)
#plt.title("Evolution of the function $h(x)$")
plt.title

fig_name = 'non_convex_function'
save(fig_name)

# %%
x_0 = np.linspace(0.,1000,100000)
y = (2*x_0-10)**2
y= x_0
eps = 0.01
x = np.sqrt((y-1.)**2+eps) -0.5*np.sqrt((y-5.)**2+eps) + 0.5*np.sqrt((y-7.)**2+eps) + 0.5*np.sqrt((y-8.)**2+eps)

plt.plot(x_0,x)
